# %% [markdown]
# # 🟣 LuminoLex Learn — Google Colab Runner
# **Powered by VERBAREX**
#
# > **Before running:** Go to `Runtime → Change runtime type` and select **T4 GPU** (or better).
#
# Run each cell **in order**, top to bottom.

# %%
# ── Cell 1: Clone the repo ────────────────────────────────────────────────────
# !git clone https://github.com/YOUR_USERNAME/luminolex-learn.git
# %cd luminolex-learn

# %%
# ── Cell 2: Install dependencies ─────────────────────────────────────────────
# !pip install -q torch transformers peft accelerate rich bitsandbytes>=0.46.1 packaging

# %%
# ── Cell 3: (If needed) Upgrade transformers for Qwen3.5 support ─────────────
# Only run this cell if Cell 4 errors with 'qwen3_5 not recognised'
# !pip install -q git+https://github.com/huggingface/transformers.git
print('Done — now go to Runtime → Restart session, then skip to Cell 4.')

# %%
# ── Cell 4: Launch LuminoLex Learn ───────────────────────────────────────────
# The interactive terminal runs inside this cell.
# Type your messages and press Enter. Use /help to see all commands.
# !python luminolex_learn.py
